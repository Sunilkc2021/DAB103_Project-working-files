# %%
import pandas as pd

# %%
new_data = pd.read_csv ("crimes_boston.csv")
print(new_data)
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA SHOOTING  \
# 0                        LARCENY ALL OTHERS      D14           808.0        N
# 1                                 VANDALISM      C11           347.0        N
# ...

# %%
new_data.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT  REPORTING_AREA SHOOTING  OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14           808.0        N  02-09-2018 13:00  2018      9
# 1      C11           347.0        N  21-08-2018 00:00  2018      8
# 2       D4           151.0        N  03-09-2018 19:27  2018      9
# 3       D4           272.0        N  03-09-2018 21:16  2018      9
# 4       B3           421.0        N  03-09-2018 21:05  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# ...

# %%
new_data

# %%
new_data = pd.read_csv ("crimes_boston.csv")

# %%
new_data
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA SHOOTING  \
# 0                        LARCENY ALL OTHERS      D14           808.0        N
# 1                                 VANDALISM      C11           347.0        N
# ...

# %%
new_data1 = new_data.rename(columns={'INCIDENT_NUMBER':'Incident Number In Records','OFFENSE_CODE':'Code Of Offense','OFFENSE_CODE_GROUP':'Group Of Offense','OFFENSE_DESCRIPTION':'Description Of Offense','REPORTING_AREA':'Area Of Reporting Code','OCCURRED_ON_DATE':'Date Of Occurrance','DAY_OF_WEEK':'Day Of Occurance','UCR_PART':'Part Of Uniform Crime Reports','STREET':'Crime Occured Street','Lat':'Latitude ','Long':'Longitude'})

# %%
new_data1
# Out:
#        Incident Number In Records  Code Of Offense      Group Of Offense  \
# 0                      I182070945              619               Larceny
# 1                      I182070943             1402             Vandalism
# 2                      I182070941             3410                 Towed
# 3                      I182070940             3114  Investigate Property
# 4                      I182070938             3114  Investigate Property
# ...                           ...              ...                   ...
# 319068              I050310906-00             3125       Warrant Arrests
# 319069              I030217815-08              111              Homicide
# 319070              I030217815-08             3125       Warrant Arrests
# 319071              I010370257-00             3125       Warrant Arrests
# 319072                  142052550             3125       Warrant Arrests
#
#                      Description Of Offense DISTRICT  Area Of Reporting Code  \
# ...

# %%
new_data1.to_csv('crimes_in_boston.csv')
